# %%
pip install yfinance
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 25.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import yfinance as yf

tickers = ['AAPL', 'MSFT', 'GOOGL', 'AMZN', 'TSLA']
data = yf.download(tickers, start="2018-01-01", end="2024-12-31")

data.to_excel('C:/Users/blaqj/OneDrive/Documents/Projects/Data Generation/plain_stock_data.xlsx')
# Out:
# [*********************100%***********************]  5 of 5 completed

# %%
import pandas as pd
data.to_csv('C:/Users/blaqj/OneDrive/Documents/Projects/Data Generation/stock Price data')
print('Data successfully moved to csv')
# Out:
# Data successfully moved to csv

# %%
import yfinance as yf
import pandas as pd

# Define the tickers you want
tickers = ['AAPL', 'MSFT', 'GOOGL', 'AMZN', 'TSLA']

# Download the stock data
data = yf.download(tickers, start="2018-01-01", end="2024-12-31", auto_adjust=False)['Adj Close']

# Save it to Excel
data.to_excel('C:/Users/blaqj/OneDrive/Documents/Projects/Data Generation/stock_data.xlsx')
# Out:
# [*********************100%***********************]  5 of 5 completed
